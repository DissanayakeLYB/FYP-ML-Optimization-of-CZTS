# %% [markdown]
# # Simple Neural Network

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import pandas as pd

# %%
pd.__version__
# Out:
# '2.0.3'

# %%
#loading the data file

df = pd.read_excel('BOM.xlsx')

# %%
df.head()
# Out:
#    Cu  Zn  Ti   S  Efficiency
# 0  20  20  20   6          73
# 1  23  21  20   8          57
# 2  23  21  21  12          80
# 3  24  22  21  12          71
# 4  25  23  21  13          77

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Cu          22 non-null     int64
#  1   Zn          22 non-null     int64
#  2   Ti          22 non-null     int64
#  3   S           22 non-null     int64
#  4   Efficiency  22 non-null     int64
# dtypes: int64(5)
# memory usage: 1012.0 bytes

# %%
df.describe()
# Out:
#               Cu         Zn         Ti          S  Efficiency
# count  22.000000  22.000000  22.000000  22.000000   22.000000
# mean   30.681818  24.818182  24.772727  19.727273   76.772727
# std     5.489265   2.593699   3.053988   7.710116   13.476370
# min    20.000000  20.000000  20.000000   6.000000   54.000000
# 25%    25.500000  23.000000  22.250000  13.250000   71.500000
# 50%    31.000000  25.000000  25.000000  21.000000   77.500000
# 75%    34.000000  27.500000  27.000000  22.750000   87.250000
# max    39.000000  29.000000  30.000000  35.000000   94.000000

# %%
#to remove a column

#data.drop(("Cu"),axis=1)

# %%
#plot data
df.plot()
# Out:
# <Axes: >

# %%
import seaborn as sns

# %%
sns.pairplot(df)
# Out:
# c:\Users\lasit\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
