# %% [markdown]
# # Simple Neural Network

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import pandas as pd

# %%
pd.__version__
# Out:
# '2.0.3'

# %%
#loading the data file

data = pd.read_excel('BOM.xlsx')

# %%
data
# Out:
#     Cu  Zn  Ti   S  Efficiency
# 0   32  23  25  20          89
# 1   35  25  28  12          56
# 2   32  26  29  13          81
# 3   35  20  20  25          86
# 4   22  20  23  35          57
# 5   26  27  21  26          60
# 6   38  24  22  16          54
# 7   29  22  28  21          86
# 8   28  26  21  25          89
# 9   32  26  26  16          60
# 10  30  28  23  19          52
# 11  20  28  26  26          54
# 12  26  30  23  21          90
# 13  40  26  25   9          74
# 14  37  22  26  15          65
# 15  26  30  22  22          71
# 16  20  22  21  37          74
# 17  31  26  23  20          63
# 18  37  25  30   8          56
# 19  21  27  29  23          88
# 20  39  21  21  19          59
# 21  32  22  22  24          91

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Cu          22 non-null     int64
#  1   Zn          22 non-null     int64
#  2   Ti          22 non-null     int64
#  3   S           22 non-null     int64
#  4   Efficiency  22 non-null     int64
# dtypes: int64(5)
# memory usage: 1012.0 bytes

# %%
data.head(10)
# Out:
#    Cu  Zn  Ti   S  Efficiency
# 0  32  23  25  20          89
# 1  35  25  28  12          56
# 2  32  26  29  13          81
# 3  35  20  20  25          86
# 4  22  20  23  35          57
# 5  26  27  21  26          60
# 6  38  24  22  16          54
# 7  29  22  28  21          86
# 8  28  26  21  25          89
# 9  32  26  26  16          60

# %%
data.describe()
# Out:
#               Cu         Zn         Ti          S  Efficiency
# count  22.000000  22.000000  22.000000  22.000000   22.000000
# mean   30.363636  24.818182  24.272727  20.545455   70.681818
# std     6.191741   2.986260   3.073416   7.229090   14.367246
# min    20.000000  20.000000  20.000000   8.000000   52.000000
# 25%    26.000000  22.000000  22.000000  16.000000   57.500000
# 50%    31.500000  25.500000  23.000000  20.500000   68.000000
# 75%    35.000000  26.750000  26.000000  24.750000   86.000000
# max    40.000000  30.000000  30.000000  37.000000   91.000000

# %%
#to remove a column

#data.drop(("Cu"),axis=1)

# %%
#plot data

data["Ti"].plot()
# Out:
# <Axes: >
